# %%
import ratinabox
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from ratinabox.Environment import Environment
from ratinabox.Agent import Agent

# %%
str(datetime.datetime.now())[:-4].replace(' ', '_').replace(':', '_').replace('.', '_')
# Out:
# '2024-05-14_22_21_54_87'

# %%
Env = Environment()
Ag = Agent(Env)

# %%
Ag.pos = [0.5, 0.5]
Ag.thigmotaxis = 0.2

# %%
minutes = 5

# %%
for i in range(int(minutes*60/Ag2.dt)):
    Ag.update()

# %%
Ag.plot_trajectory(color='changing', colorbar=True, gridlines=True)

plt.show()

# %%
df = pd.DataFrame(Ag.history)
df.head()
# Out:
#      t                                         pos  distance_travelled  \
# 0  0.1  [0.053928816877986396, 0.7359364718947229]            0.006204
# 1  0.2   [0.04818913363797734, 0.7354244763403923]            0.011966
# 2  0.3  [0.044516990477907414, 0.7324563678573607]            0.016688
# 3  0.4    [0.0431589617750367, 0.7317881677460332]            0.018201
# 4  0.5   [0.03659224471665747, 0.7313273443726187]            0.024784
#
#                                                vel   rot_vel  \
# 0      [-0.06112271735037644, 0.01061316425550185] -0.179423
# 1    [-0.05739683240009057, -0.005119955543305688]  2.608944
# 2    [-0.03672143160069925, -0.029681084830316395]  5.908120
# 3  [-0.013580287028707172, -0.0066820011132751045] -2.224948
# 4    [-0.06566717058379225, -0.004608233734144651] -3.872241
#
#                                   head_direction
# 0     [-0.9862631223999155, 0.16518187973857543]
# 1  [-0.9999911674832787, -0.0042029698344562974]
# ...

# %%
Ag.history
# Out:
# {'t': [0.1,
#   0.2,
#   0.30000000000000004,
#   0.4,
#   0.5,
#   0.6,
#   0.7,
#   0.7999999999999999,
#   0.8999999999999999,
#   0.9999999999999999,
#   1.0999999999999999,
#   1.2,
#   1.3,
#   1.4000000000000001,
#   1.5000000000000002,
#   1.6000000000000003,
#   1.7000000000000004,
#   1.8000000000000005,
#   1.9000000000000006,
#   2.0000000000000004,
#   2.1000000000000005,
#   2.2000000000000006,
#   2.3000000000000007,
#   2.400000000000001,
#   2.500000000000001,
#   2.600000000000001,
#   2.700000000000001,
#   2.800000000000001,
#   2.9000000000000012,
#   3.0000000000000013,
#   3.1000000000000014,
#   3.2000000000000015,
#   3.3000000000000016,
#   3.4000000000000017,
#   3.5000000000000018,
#   3.600000000000002,
#   3.700000000000002,
#   3.800000000000002,
#   3.900000000000002,
#   4.000000000000002,
#   4.100000000000001,
#   4.200000000000001,
#   4.300000000000001,
#   4.4,
#   4.5,
#   4.6,
#   4.699999999999999,
#   4.799999999999999,
# ...

# %%
Env.plot_environment(gridlines=True, plot_objects=True)
# Out:
# (<Figure size 300x300 with 1 Axes>, <Axes: >)

# %%
help(Ag.plot_trajectory)
# Out:
# Help on method plot_trajectory in module ratinabox.Agent:
#
# plot_trajectory(t_start=0, t_end=None, framerate=10, fig=None, ax=None, plot_all_agents=False, color=None, colorbar=False, autosave=None, **kwargs) method of ratinabox.Agent.Agent instance
#     Plots the trajectory between t_start (seconds) and t_end (defaulting to the last time available)
#     Args:
#         • t_start: start time in seconds
#         • t_end: end time in seconds (default = self.history["t"][-1])
#         • framerate: how many scatter points / per second of motion to display
#         • fig, ax: the fig, ax to plot on top of, optional, if not provided used self.Environment.plot_Environment().
#           This can be used to plot trajectory on top of receptive fields etc.
#         • plot_all_agents: if True, this will plot the trajectory of all agents in the list self.Environment.Agents
# ...

# %%
x, y = [x0, y0 for x0, y0 in df['pos'].values]
# Out:
#   Cell In[20], line 1
#     x, y = [x0, y0 for x0, y0 in df['pos'].values]
#             ^
# SyntaxError: did you forget parentheses around the comprehension target?

# %%
for i in df['pos'].values[:3]:
    print(i, i[0], i[1])
# Out:
# [0.053928816877986396, 0.7359364718947229] 0.053928816877986396 0.7359364718947229
# [0.04818913363797734, 0.7354244763403923] 0.04818913363797734 0.7354244763403923
# [0.044516990477907414, 0.7324563678573607] 0.044516990477907414 0.7324563678573607
